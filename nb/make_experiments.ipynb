# %%
# !pip install oyaml
# Out:
# Collecting oyaml
#   Downloading https://files.pythonhosted.org/packages/d7/18/89b8898d1878a8dda9ff9e8219bb9756c959712a1324800fc4df9d641dd1/oyaml-0.5-py2.py3-none-any.whl
# Requirement already satisfied: pyyaml in /home/femianjc/anaconda3/lib/python3.6/site-packages (from oyaml) (3.12)
# Installing collected packages: oyaml
# Successfully installed oyaml-0.5

# %%
""" Generate modules for all combinations of settings we plan to test.

"""
from collections import OrderedDict
import itertools
import pandas as pd

# List options in the order that you want to test.
# Put the hypothetical best values first; that way 
# the first experments will assume the best values
# for all options

OPTIONS = OrderedDict()  # for python2 compatability

OPTIONS['FUSION'] = ['early_fusion', 'late_fusion_add', 'late_fusion_cat']

OPTIONS['OBB_PARAMETRIZATION'] = [ 'vector_and_width', 'angle_length_width', 'four_points', 'two_vectors']

OPTIONS['SYNTHETIC'] = ['no_pretrain', 'pretrain']

OPTIONS['CHANNEL_DROPOUT'] = ['cdrop', 'no_cdrop']

OPTIONS['CLASS_LOSS'] = ['hinge_loss', 'xent_loss']

OPTIONS['REGRESSION_LOSS'] = ['smooth_L1', 'L2']

OPTIONS['AUG_JITTER'] = ['no_jitter', 'jitter']


COMBOS = [ reversed(combo) for combo in itertools.product(*reversed(OPTIONS.values()))]

# %%
EXPERIMENTS = pd.DataFrame(COMBOS, columns=OPTIONS.keys())
EXPERIMENTS
# Out:
#               FUSION OBB_PARAMETRIZATION    SYNTHETIC CHANNEL_DROPOUT  \
# 0       early_fusion    vector_and_width  no_pretrain           cdrop
# 1    late_fusion_add    vector_and_width  no_pretrain           cdrop
# 2    late_fusion_cat    vector_and_width  no_pretrain           cdrop
# 3       early_fusion  angle_length_width  no_pretrain           cdrop
# 4    late_fusion_add  angle_length_width  no_pretrain           cdrop
# 5    late_fusion_cat  angle_length_width  no_pretrain           cdrop
# 6       early_fusion         four_points  no_pretrain           cdrop
# 7    late_fusion_add         four_points  no_pretrain           cdrop
# 8    late_fusion_cat         four_points  no_pretrain           cdrop
# 9       early_fusion         two_vectors  no_pretrain           cdrop
# 10   late_fusion_add         two_vectors  no_pretrain           cdrop
# 11   late_fusion_cat         two_vectors  no_pretrain           cdrop
# 12      early_fusion    vector_and_width     pretrain           cdrop
# 13   late_fusion_add    vector_and_width     pretrain           cdrop
# 14   late_fusion_cat    vector_and_width     pretrain           cdrop
# 15      early_fusion  angle_length_width     pretrain           cdrop
# 16   late_fusion_add  angle_length_width     pretrain           cdrop
# 17   late_fusion_cat  angle_length_width     pretrain           cdrop
# 18      early_fusion         four_points     pretrain           cdrop
# 19   late_fusion_add         four_points     pretrain           cdrop
# 20   late_fusion_cat         four_points     pretrain           cdrop
# 21      early_fusion         two_vectors     pretrain           cdrop
# 22   late_fusion_add         two_vectors     pretrain           cdrop
# 23   late_fusion_cat         two_vectors     pretrain           cdrop
# 24      early_fusion    vector_and_width  no_pretrain        no_cdrop
# 25   late_fusion_add    vector_and_width  no_pretrain        no_cdrop
# 26   late_fusion_cat    vector_and_width  no_pretrain        no_cdrop
# 27      early_fusion  angle_length_width  no_pretrain        no_cdrop
# 28   late_fusion_add  angle_length_width  no_pretrain        no_cdrop
# 29   late_fusion_cat  angle_length_width  no_pretrain        no_cdrop
# ..               ...                 ...          ...             ...
# 354     early_fusion         four_points     pretrain           cdrop
# 355  late_fusion_add         four_points     pretrain           cdrop
# 356  late_fusion_cat         four_points     pretrain           cdrop
# 357     early_fusion         two_vectors     pretrain           cdrop
# 358  late_fusion_add         two_vectors     pretrain           cdrop
# 359  late_fusion_cat         two_vectors     pretrain           cdrop
# 360     early_fusion    vector_and_width  no_pretrain        no_cdrop
# 361  late_fusion_add    vector_and_width  no_pretrain        no_cdrop
# 362  late_fusion_cat    vector_and_width  no_pretrain        no_cdrop
# 363     early_fusion  angle_length_width  no_pretrain        no_cdrop
# 364  late_fusion_add  angle_length_width  no_pretrain        no_cdrop
# 365  late_fusion_cat  angle_length_width  no_pretrain        no_cdrop
# 366     early_fusion         four_points  no_pretrain        no_cdrop
# 367  late_fusion_add         four_points  no_pretrain        no_cdrop
# 368  late_fusion_cat         four_points  no_pretrain        no_cdrop
# 369     early_fusion         two_vectors  no_pretrain        no_cdrop
# 370  late_fusion_add         two_vectors  no_pretrain        no_cdrop
# 371  late_fusion_cat         two_vectors  no_pretrain        no_cdrop
# 372     early_fusion    vector_and_width     pretrain        no_cdrop
# 373  late_fusion_add    vector_and_width     pretrain        no_cdrop
# 374  late_fusion_cat    vector_and_width     pretrain        no_cdrop
# 375     early_fusion  angle_length_width     pretrain        no_cdrop
# 376  late_fusion_add  angle_length_width     pretrain        no_cdrop
# 377  late_fusion_cat  angle_length_width     pretrain        no_cdrop
# 378     early_fusion         four_points     pretrain        no_cdrop
# 379  late_fusion_add         four_points     pretrain        no_cdrop
# 380  late_fusion_cat         four_points     pretrain        no_cdrop
# 381     early_fusion         two_vectors     pretrain        no_cdrop
# 382  late_fusion_add         two_vectors     pretrain        no_cdrop
# 383  late_fusion_cat         two_vectors     pretrain        no_cdrop
#
#      CLASS_LOSS REGRESSION_LOSS AUG_JITTER
# 0    hinge_loss       smooth_L1  no_jitter
# 1    hinge_loss       smooth_L1  no_jitter
# 2    hinge_loss       smooth_L1  no_jitter
# 3    hinge_loss       smooth_L1  no_jitter
# 4    hinge_loss       smooth_L1  no_jitter
# 5    hinge_loss       smooth_L1  no_jitter
# 6    hinge_loss       smooth_L1  no_jitter
# 7    hinge_loss       smooth_L1  no_jitter
# 8    hinge_loss       smooth_L1  no_jitter
# 9    hinge_loss       smooth_L1  no_jitter
# 10   hinge_loss       smooth_L1  no_jitter
# 11   hinge_loss       smooth_L1  no_jitter
# 12   hinge_loss       smooth_L1  no_jitter
# 13   hinge_loss       smooth_L1  no_jitter
# 14   hinge_loss       smooth_L1  no_jitter
# 15   hinge_loss       smooth_L1  no_jitter
# 16   hinge_loss       smooth_L1  no_jitter
# 17   hinge_loss       smooth_L1  no_jitter
# 18   hinge_loss       smooth_L1  no_jitter
# 19   hinge_loss       smooth_L1  no_jitter
# 20   hinge_loss       smooth_L1  no_jitter
# 21   hinge_loss       smooth_L1  no_jitter
# 22   hinge_loss       smooth_L1  no_jitter
# 23   hinge_loss       smooth_L1  no_jitter
# 24   hinge_loss       smooth_L1  no_jitter
# 25   hinge_loss       smooth_L1  no_jitter
# 26   hinge_loss       smooth_L1  no_jitter
# 27   hinge_loss       smooth_L1  no_jitter
# 28   hinge_loss       smooth_L1  no_jitter
# 29   hinge_loss       smooth_L1  no_jitter
# ..          ...             ...        ...
# 354   xent_loss              L2     jitter
# 355   xent_loss              L2     jitter
# 356   xent_loss              L2     jitter
# 357   xent_loss              L2     jitter
# 358   xent_loss              L2     jitter
# 359   xent_loss              L2     jitter
# 360   xent_loss              L2     jitter
# 361   xent_loss              L2     jitter
# 362   xent_loss              L2     jitter
# 363   xent_loss              L2     jitter
# 364   xent_loss              L2     jitter
# 365   xent_loss              L2     jitter
# 366   xent_loss              L2     jitter
# 367   xent_loss              L2     jitter
# 368   xent_loss              L2     jitter
# 369   xent_loss              L2     jitter
# 370   xent_loss              L2     jitter
# 371   xent_loss              L2     jitter
# 372   xent_loss              L2     jitter
# 373   xent_loss              L2     jitter
# 374   xent_loss              L2     jitter
# 375   xent_loss              L2     jitter
# 376   xent_loss              L2     jitter
# 377   xent_loss              L2     jitter
# 378   xent_loss              L2     jitter
# 379   xent_loss              L2     jitter
# 380   xent_loss              L2     jitter
# 381   xent_loss              L2     jitter
# 382   xent_loss              L2     jitter
# 383   xent_loss              L2     jitter
#
# [384 rows x 7 columns]

# %%
combo = EXPERIMENTS.iloc[10]

# %%
dict(combo)
# Out:
# {'FUSION': 'late_fusion_add',
#  'OBB_PARAMETRIZATION': 'two_vectors',
#  'SYNTHETIC': 'no_pretrain',
#  'CHANNEL_DROPOUT': 'cdrop',
#  'CLASS_LOSS': 'hinge_loss',
#  'REGRESSION_LOSS': 'smooth_L1',
#  'AUG_JITTER': 'no_jitter'}

# %%
def save_options(f):
    for k, v in combo.items():
        print('{}: {}'.format(k,v), file=f)

import sys        
save_options(sys.stdout)
# Out:
# FUSION: late_fusion_add
# OBB_PARAMETRIZATION: two_vectors
# SYNTHETIC: no_pretrain
# CHANNEL_DROPOUT: cdrop
# CLASS_LOSS: hinge_loss
# REGRESSION_LOSS: smooth_L1
# AUG_JITTER: no_jitter

# %%
import oyaml as yaml
rec = OrderedDict()
rec['EXPERIMENT'] = combo.name
rec.update(combo)
print(yaml.dump(rec, default_flow_style=False))
# Out:
# EXPERIMENT: 10
# FUSION: late_fusion_add
# OBB_PARAMETRIZATION: two_vectors
# SYNTHETIC: no_pretrain
# CHANNEL_DROPOUT: cdrop
# CLASS_LOSS: hinge_loss
# REGRESSION_LOSS: smooth_L1
# AUG_JITTER: no_jitter

# %%
import os
def make_relpath(combo):
    return '-'.join(('{:05}'.format(combo.name),)+ tuple(combo))

# %%
make_relpath(combo)
# Out:
# '00010-late_fusion_add-two_vectors-no_pretrain-cdrop-hinge_loss-smooth_L1-no_jitter'

# %%
INT_DATA = '../data/interim/'

# %%
print(yaml.dump(OPTIONS))
# Out:
# FUSION: [early_fusion, late_fusion_add, late_fusion_cat]
# OBB_PARAMETRIZATION: [vector_and_width, angle_length_width, four_points, two_vectors]
# SYNTHETIC: [no_pretrain, pretrain]
# CHANNEL_DROPOUT: [cdrop, no_cdrop]
# CLASS_LOSS: [hinge_loss, xent_loss]
# REGRESSION_LOSS: [smooth_L1, L2]
# AUG_JITTER: [no_jitter, jitter]

# %%
from tqdm import tqdm

# %%
import oyaml as yaml

def make_experiments(options):
    # Save the options 
    with open(os.path.join(INT_DATA, 'options.yml'), 'w') as f:
        yaml.dump(options, f, default_flow_style=False)
        
    # Save the master list of experiments
    combos = [ reversed(combo) for combo in itertools.product(*reversed(options.values()))]
    experiments = pd.DataFrame(combos, columns=options.keys())
    experiments.to_csv(os.path.join(INT_DATA, 'experiments.csv'))
    
    # Make s folder and config file for each experiment
    for i, combo in tqdm(experiments.iterrows(), "generating configs"):
        dirname = '{:05}'.format(combo.name)

        rec = OrderedDict()
        rec['NUMBER'] = combo.name
        rec['NAME'] = '-'.join((dirname,)+ tuple(combo))
        rec.update(combo)
        
        os.makedirs(os.path.join(INT_DATA, 'experiments', dirname), exist_ok=True)
        with open(os.path.join(INT_DATA, 'experiments', dirname, 'config.yml'), 'w') as f:
            yaml.dump(rec, f, default_flow_style=False)

# %%
make_experiments(OPTIONS)
# Out:
# generating configs: 384it [00:00, 825.37it/s]
